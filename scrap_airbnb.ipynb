# %%
from urllib import request
from bs4 import BeautifulSoup
import pandas as pd

# %%
lieu='PARIS LA DEFENSE ARENA'.replace(' ', '-')
url="https://www.airbnb.fr/s/"+lieu+"/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=1&date_picker_type=calendar&checkin=2023-01-01&checkout=2022-01-02&source=structured_search_input_header&search_type=search_query"
request_text = request.urlopen(url).read()
htmlpage= BeautifulSoup(request_text, "html")

# %%
hotels=[]
for item in htmlpage.findAll('div',{'class':'lwy0wad l1tup9az dir dir-ltr'}):
    hotel={}
    hotel['Titre']=item.find('div',{'class':'t1jojoys dir dir-ltr'}).text.replace('\n','')
    hotel['Type']=item.find('span',{'class':'t6mzqp7 dir dir-ltr'}).text.replace('\n','')
    hotel['Lit']=item.find('div',{'class':'f15liw5s s1cjsi4j dir dir-ltr'}).text.replace('\n','')
    hotel['Prix (€)']=item.find('div',{'class':'_tt122m'}).text.replace('\n','').replace('€ au total','')
    item_rating=item.find('span',{'class':'r1dxllyb dir dir-ltr'})
    if(item_rating != None):
        rating= item_rating.text.replace(')','').split('(')
        if(len(rating)==2):
            hotel['Note (sur 5)']=rating[0]
            hotel['Nombre de revues']=rating[1]
    hotel['Link']="https://www.airbnb.fr/"+str(item.find('div',{'class':'c14whb16 dir dir-ltr'}).find('a')['href'])
    hotels.append(hotel)

# %%
df= pd.DataFrame(hotels)
df
# Out:
#                                     Titre  \
# 0               Chambre privée ⋅ Nanterre
# 1   Appartement en résidence ⋅ Courbevoie
# 2               Chambre privée ⋅ Nanterre
# 3                  Appartement ⋅ Nanterre
# 4                Appartement ⋅ Courbevoie
# 5               Chambre privée ⋅ Colombes
# 6                Appartement ⋅ Courbevoie
# 7               Chambre privée ⋅ Colombes
# 8               Chambre privée ⋅ Nanterre
# 9                Appartement ⋅ Courbevoie
# 10  Appartement en résidence ⋅ Courbevoie
# 11            Chambre privée ⋅ Courbevoie
# 12               Appartement ⋅ Courbevoie
# 13               Appartement ⋅ Courbevoie
# 14               Appartement ⋅ Courbevoie
# 15            Chambre privée ⋅ Courbevoie
# 16      Appartement ⋅ La Garenne-Colombes
# 17                    Logement ⋅ Nanterre
#
#                                                  Type            Lit Prix (€)  \
# 0                      Chambre proche défense U Arena    Particulier     436
# 1   Charmant studio avec terrasse & vue, proche Pa...    Particulier     650
# 2                                 Chambre privée parc    Particulier     238
